# %% [markdown]
# # Predict next month product demands based on historical product demand

# %% [markdown]
# ## This is Time Series Analysis. We need to import all the libraries to do our time series predictive analysis.

# %%
! pip install numpy
# Out:
# Requirement already satisfied: numpy in c:\users\vadim\anaconda3\lib\site-packages (1.20.2)

# %%
# Just to ignore warnings
import warnings
warnings.filterwarnings('ignore')

# Importing libraries 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import datetime
sns.set()
import plotly as py
# Import dependencies
import plotly.graph_objs as go
import ipywidgets as widgets
from scipy import special
# Configure Plotly to be rendered inline in the notebook.
py.offline.init_notebook_mode(connected=True)
import itertools
plt.style.use('fivethirtyeight')
import statsmodels.api as sm
import matplotlib
matplotlib.rcParams['axes.labelsize'] = 14
matplotlib.rcParams['xtick.labelsize'] = 12
matplotlib.rcParams['ytick.labelsize'] = 12
matplotlib.rcParams['text.color'] = 'k'
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# ## Read data set from manufacturer and explore the features

# %%
df = pd.read_csv('HPD2.csv', parse_dates=['Date'])
df.head()
# Out:
#    Product_Code Warehouse Product_Category       Date  Order_Demand  \
# 0  Product_0608    Whse_C     Category_001 2011-09-27             5
# 1  Product_1933    Whse_C     Category_001 2011-09-27            23
# 2  Product_1925    Whse_C     Category_001 2011-12-13            40
# 3  Product_0609    Whse_J     Category_001 2011-12-13             1
# 4  Product_1925    Whse_C     Category_001 2011-12-16            50
#
#    Unnamed: 5  Unnamed: 6
# 0         NaN         NaN
# 1         NaN        28.0
# 2         NaN         NaN
# 3         NaN         NaN
# 4         NaN         NaN

# %%
df.columns
# Out:
# Index(['Product_Code', 'Warehouse', 'Product_Category', 'Date', 'Order_Demand',
#        'Unnamed: 5', 'Unnamed: 6'],
#       dtype='object')

# %%
df.nunique()
# Out:
# Product_Code         278
# Warehouse              4
# Product_Category       1
# Date                1402
# Order_Demand         246
# Unnamed: 5             0
# Unnamed: 6             5
# dtype: int64

# %% [markdown]
# ### 1. Product Code (categorical): 2160 products
# ### 2. Warehouse (categorical): 4 warehouses
# ### 3. Product category (categorical): 33 categories¶
# ### 4. Date (date): demand fulfillment date
# ### 5. Order demanded (integer): target demand value

# %%
df.Product_Code.unique()
# Out:
# array(['Product_0608', 'Product_1933', 'Product_1925', 'Product_0609',
#        'Product_0713', 'Product_0269', 'Product_0620', 'Product_1757',
#        'Product_0719', 'Product_0793', 'Product_0695', 'Product_0805',
#        'Product_0258', 'Product_0260', 'Product_0750', 'Product_0765',
#        'Product_0631', 'Product_0808', 'Product_1948', 'Product_0767',
#        'Product_1963', 'Product_0632', 'Product_0614', 'Product_1862',
#        'Product_1935', 'Product_0613', 'Product_0623', 'Product_0404',
#        'Product_0621', 'Product_1763', 'Product_0625', 'Product_1853',
#        'Product_1869', 'Product_1926', 'Product_1938', 'Product_1954',
#        'Product_1864', 'Product_0712', 'Product_0763', 'Product_0797',
#        'Product_0799', 'Product_0819', 'Product_0796', 'Product_0821',
#        'Product_1770', 'Product_0815', 'Product_0748', 'Product_0776',
#        'Product_0789', 'Product_0816', 'Product_0627', 'Product_0700',
#        'Product_0790', 'Product_0786', 'Product_0720', 'Product_1761',
#        'Product_1750', 'Product_1762', 'Product_1953', 'Product_1759',
#        'Product_0806', 'Product_0706', 'Product_0707', 'Product_0606',
#        'Product_0618', 'Product_0617', 'Product_0624', 'Product_0756',
#        'Product_0757', 'Product_0760', 'Product_0761', 'Product_0768',
#        'Product_0769', 'Product_0772', 'Product_0773', 'Product_0263',
#        'Product_0731', 'Product_0792', 'Product_0795', 'Product_0711',
#        'Product_0791', 'Product_0605', 'Product_0615', 'Product_1952',
#        'Product_1752', 'Product_1755', 'Product_0704', 'Product_1871',
#        'Product_0781', 'Product_0782', 'Product_0785', 'Product_0770',
#        'Product_0256', 'Product_0262', 'Product_0822', 'Product_0817',
#        'Product_1749', 'Product_1852', 'Product_1857', 'Product_0267',
#        'Product_0619', 'Product_1949', 'Product_1767', 'Product_1768',
#        'Product_1769', 'Product_1771', 'Product_0261', 'Product_0629',
#        'Product_0755', 'Product_1936', 'Product_1865', 'Product_0626',
#        'Product_0729', 'Product_0741', 'Product_0779', 'Product_0732',
#        'Product_0818', 'Product_1875', 'Product_0739', 'Product_0705',
#        'Product_0697', 'Product_0738', 'Product_0723', 'Product_0784',
#        'Product_0780', 'Product_0722', 'Product_0798', 'Product_0743',
#        'Product_1851', 'Product_0699', 'Product_0754', 'Product_0622',
#        'Product_1861', 'Product_0703', 'Product_0747', 'Product_0783',
#        'Product_0628', 'Product_0733', 'Product_0794', 'Product_1870',
#        'Product_1872', 'Product_0746', 'Product_1931', 'Product_1760',
#        'Product_0724', 'Product_0749', 'Product_0691', 'Product_0777',
#        'Product_0762', 'Product_0787', 'Product_0714', 'Product_0696',
#        'Product_0740', 'Product_0264', 'Product_0271', 'Product_0405',
#        'Product_0721', 'Product_0701', 'Product_0866', 'Product_0268',
#        'Product_0266', 'Product_0715', 'Product_1758', 'Product_0610',
#        'Product_1858', 'Product_1932', 'Product_1941', 'Product_0766',
#        'Product_0265', 'Product_0764', 'Product_0774', 'Product_0804',
#        'Product_0867', 'Product_1923', 'Product_0607', 'Product_0775',
#        'Product_0788', 'Product_0807', 'Product_0728', 'Product_0730',
#        'Product_1867', 'Product_0604', 'Product_0603', 'Product_0752',
#        'Product_1877', 'Product_0257', 'Product_0710', 'Product_1753',
#        'Product_0702', 'Product_1868', 'Product_1874', 'Product_0270',
#        'Product_0259', 'Product_0758', 'Product_1947', 'Product_0727',
#        'Product_0737', 'Product_0751', 'Product_0759', 'Product_1856',
#        'Product_0745', 'Product_0742', 'Product_0693', 'Product_1921',
#        'Product_0803', 'Product_1920', 'Product_0725', 'Product_0601',
#        'Product_1937', 'Product_1929', 'Product_1754', 'Product_0716',
#        'Product_0744', 'Product_1930', 'Product_0600', 'Product_1940',
#        'Product_0709', 'Product_1955', 'Product_0616', 'Product_0602',
#        'Product_1855', 'Product_1866', 'Product_0708', 'Product_1943',
#        'Product_1927', 'Product_1939', 'Product_0726', 'Product_0753',
#        'Product_1944', 'Product_0735', 'Product_1942', 'Product_1860',
#        'Product_1859', 'Product_1922', 'Product_0630', 'Product_0820',
#        'Product_1876', 'Product_1961', 'Product_0802', 'Product_1945',
#        'Product_0801', 'Product_1854', 'Product_0814', 'Product_1946',
#        'Product_1934', 'Product_0717', 'Product_1956', 'Product_0800',
#        'Product_1951', 'Product_0771', 'Product_0736', 'Product_0718',
#        'Product_1924', 'Product_1964', 'Product_0633', 'Product_0698',
#        'Product_0810', 'Product_0813', 'Product_1764', 'Product_0734',
#        'Product_1756', 'Product_1928', 'Product_1919', 'Product_0811',
#        'Product_0812', 'Product_1950', 'Product_1962', 'Product_0611',
#        'Product_0692', 'Product_1965', 'Product_0778', 'Product_0612',
#        'Product_0809', 'Product_0694', 'Product_1751', 'Product_1873',
#        'Product_1863', 'Product_1850'], dtype=object)

# %%
df.Product_Category.unique()
# Out:
# array(['Category_001'], dtype=object)

# %%
df['Product_Category'].value_counts()
# Out:
# Category_001    96841
# Name: Product_Category, dtype: int64

# %% [markdown]
# ## Group by product category and make it in order by count. We want to get the order demand for top three categories.

# %%
Cat_fltr = df.groupby(['Product_Category']).size().reset_index(name='Cat_count').sort_values(['Cat_count'],ascending=False)
Cat_fltr.head(10)
# Out:
#   Product_Category  Cat_count
# 0     Category_001      96841

# %%
#df.groupby('Product_Category')['Order_Demand'].sum()

# %% [markdown]
# ## Let's look at the highest product code in demand as well.

# %%
Code_fltr = df.groupby(['Product_Code']).size().reset_index(name='Code_count').sort_values(['Code_count'],ascending=False)
Code_fltr.head(10)
# Out:
#      Product_Code  Code_count
# 38   Product_0620        9367
# 31   Product_0613        6029
# 26   Product_0608        4769
# 36   Product_0618        2164
# 45   Product_0627        1755
# 49   Product_0631        1600
# 24   Product_0606        1555
# 39   Product_0621        1430
# 32   Product_0614        1342
# 151  Product_0790        1227

# %% [markdown]
# ## Categories  1, 5 and 19 are with top three counts. We are using Category_001 as an example to predict next month product category demand

# %% [markdown]
# ## Let's make our Category_001 as a separate data frame and start preparing it for our forecast

# %%
Category_001 = df.loc[df['Product_Category'] == 'Category_001'] #.sort_values(['Date'],ascending=False)
Category_001.describe()
# Out:
#        Order_Demand  Unnamed: 5    Unnamed: 6
# count  96841.000000         0.0      5.000000
# mean      17.997914         NaN  18433.400000
# std       53.364740         NaN  18193.527223
# min        1.000000         NaN     28.000000
# 25%        1.000000         NaN    957.000000
# 50%        5.000000         NaN  22172.000000
# 75%       15.000000         NaN  25866.000000
# max     2075.000000         NaN  43144.000000

# %% [markdown]
# ## Look at the available start and end date stamps

# %%
Category_001['Date'].min(), Category_001['Date'].max()
# Out:
# (Timestamp('2011-09-27 00:00:00'), Timestamp('2017-01-06 00:00:00'))

# %% [markdown]
# ## Data Preprocessing - droping columns

# %%
cols = [ 'Product_Code', 'Warehouse', 'Product_Category']
Category_001.drop(cols, axis=1, inplace=True)
Category_001 = Category_001.sort_values('Date')
Category_001.isnull().sum()
# Out:
# Date                0
# Order_Demand        0
# Unnamed: 5      96841
# Unnamed: 6      96836
# dtype: int64

# %% [markdown]
# ## We have daily data. We want to aggregate demand for Category 001 by year and month - grouping by month.

# %%
Category_001[['year','month']] = Category_001.Date.apply(lambda x: pd.Series(x.strftime("%Y,%m").split(",")))
Category_001 = Category_001.groupby(['year', 'month', ])[['Order_Demand']].sum().reset_index()
Category_001=Category_001[['year', 'month', 'Order_Demand']]
Category_001
# Out:
#     year month  Order_Demand
# 0   2011    09            28
# 1   2011    12           957
# 2   2012    01         22172
# 3   2012    02         25866
# 4   2012    03         30002
# ..   ...   ...           ...
# 58  2016    09         33249
# 59  2016    10         30938
# 60  2016    11         35011
# 61  2016    12         43144
# 62  2017    01            29
#
# [63 rows x 3 columns]

# %% [markdown]
# ## Create pivot table to look at monthly product demand

# %%
Category_001_pivot = Category_001.pivot('month', 'year', 'Order_Demand')
Category_001_pivot
# Out:
# year    2011     2012     2013     2014     2015     2016  2017
# month
# 01       NaN  22172.0  22281.0  26276.0  35569.0  31214.0  29.0
# 02       NaN  25866.0  29030.0  26665.0  37465.0  33834.0   NaN
# 03       NaN  30002.0  26776.0  36264.0  34587.0  39711.0   NaN
# 04       NaN  20960.0  24464.0  25970.0  30803.0  32248.0   NaN
# 05       NaN  20391.0  21452.0  28438.0  25452.0  26485.0   NaN
# 06       NaN  21214.0  22989.0  29207.0  36159.0  35364.0   NaN
# 07       NaN  20313.0  30267.0  32801.0  34183.0  31433.0   NaN
# 08       NaN  18159.0  24993.0  28950.0  29797.0  26377.0   NaN
# 09      28.0  19864.0  27373.0  30246.0  27524.0  33249.0   NaN
# 10       NaN  27648.0  29258.0  39195.0  36550.0  30938.0   NaN
# 11       NaN  25078.0  27088.0  31200.0  30568.0  35011.0   NaN
# 12     957.0  21271.0  28882.0  32328.0  28926.0  43144.0   NaN

# %%
plt.figure(figsize=(15, 5))
sns.heatmap(Category_001_pivot, annot = True, cmap = "YlGnBu")
# Out:
# <AxesSubplot:xlabel='year', ylabel='month'>

# %%
plt.figure(figsize=(15, 5))
sns.boxplot(x="year", y="Order_Demand", data=Category_001)
# Out:
# <AxesSubplot:xlabel='year', ylabel='Order_Demand'>

# %% [markdown]
# ## Indexing with Time Series Data

# %%
#df['Date'] = pd.to_datetime(df['Date'], errors='coerce')
#Category_001 = Category_001.set_index('Date')
#Category_001.index
Category_001 = Category_001.drop(Category_001.index[[0,1]])
Category_001 = Category_001.drop(Category_001.index[[-1]])
Category_001.tail()
# Out:
#             year month  Order_Demand
# Timestamp
# 2017-01-31  2016    07         31433
# 2017-02-28  2016    08         26377
# 2017-03-31  2016    09         33249
# 2017-04-30  2016    10         30938
# 2017-05-31  2016    11         35011

# %% [markdown]
# ## Combine dates and create datetime index to prepare Category_001 dataset for time series forecast

# %%
Category_001['Timestamp'] = pd.date_range('20120731', periods = 60, freq = 'M')

# %%
y = Category_001.loc[:, ('Order_Demand')]
y.head(10),
# Out:
# (Timestamp
#  2012-07-31    22172
#  2012-08-31    25866
#  2012-09-30    30002
#  2012-10-31    20960
#  2012-11-30    20391
#  2012-12-31    21214
#  2013-01-31    20313
#  2013-02-28    18159
#  2013-03-31    19864
#  2013-04-30    27648
#  Name: Order_Demand, dtype: int64,)

# %%
Category_001 = Category_001.set_index('Timestamp')
Category_001.index
# Out:
# DatetimeIndex(['2012-07-31', '2012-08-31', '2012-09-30', '2012-10-31',
#                '2012-11-30', '2012-12-31', '2013-01-31', '2013-02-28',
#                '2013-03-31', '2013-04-30', '2013-05-31', '2013-06-30',
#                '2013-07-31', '2013-08-31', '2013-09-30', '2013-10-31',
#                '2013-11-30', '2013-12-31', '2014-01-31', '2014-02-28',
#                '2014-03-31', '2014-04-30', '2014-05-31', '2014-06-30',
#                '2014-07-31', '2014-08-31', '2014-09-30', '2014-10-31',
#                '2014-11-30', '2014-12-31', '2015-01-31', '2015-02-28',
#                '2015-03-31', '2015-04-30', '2015-05-31', '2015-06-30',
#                '2015-07-31', '2015-08-31', '2015-09-30', '2015-10-31',
#                '2015-11-30', '2015-12-31', '2016-01-31', '2016-02-29',
#                '2016-03-31', '2016-04-30', '2016-05-31', '2016-06-30',
#                '2016-07-31', '2016-08-31', '2016-09-30', '2016-10-31',
#                '2016-11-30', '2016-12-31', '2017-01-31', '2017-02-28',
#                '2017-03-31', '2017-04-30', '2017-05-31', '2017-06-30'],
#               dtype='datetime64[ns]', name='Timestamp', freq=None)

# %%
#y = Category_001['Order_Demand'].resample('MS').mean()

# %%
df.index = pd.to_datetime(df.index, unit='s')

# %% [markdown]
# ## Visualizing Order Demand for Category_001

# %%
y.plot(figsize=(13,6), title= 'Category_001 Observed Order_Demand', fontsize=14, color="Blue")
plt.show()

# %%
from statsmodels.tsa.stattools import adfuller

# %% [markdown]
# ## Split data for each category into train and test sets - 80/20%

# %%
#train = y[:50]
#test = y[-20:]
#train.shape, test.shape

# %%
train = y.loc['2012-08-31':'2015-12-31']
test = y.loc['2015-12-31':]
train.shape, test.shape
# Out:
# ((41,), (19,))

# %%
train.index = pd.DatetimeIndex(train.index.values, freq=train.index.inferred_freq)
test.index = pd.DatetimeIndex(test.index.values, freq=test.index.inferred_freq)

# %% [markdown]
# ## Visualize train and test sets

# %%
train.plot(figsize=(15,6), title= 'Category_001 - Train and Test Data', fontsize=12,color="Green")
test.plot(figsize=(15,6), fontsize=14, color="Red")
plt.show();

# %% [markdown]
# ## Simple smoothing

# %%
from statsmodels.tsa.api import ExponentialSmoothing, SimpleExpSmoothing, Holt

# %%
#simple smoothing
s_avg = test.copy()
fit_s = SimpleExpSmoothing(train).fit(smoothing_level=0.2,optimized=False)
s_avg['S_Smooth'] = fit_s.forecast(len(test))
plt.figure(figsize=(14,6))
plt.plot(train, label='Train',color="Green")
plt.plot(test, label='Test')
plt.plot(s_avg['S_Smooth'], label='S_Smooth',color="Red")
plt.title("Simple Smoothing")
plt.legend(loc='best')
plt.show()

# %%
import math
from sklearn.metrics import mean_squared_error
SS_RMSE = math.sqrt(mean_squared_error(test, s_avg.S_Smooth))
print('SS_RMSE: %f' % SS_RMSE)
# Out:
# SS_RMSE: 4247.628253

# %%
from sklearn.metrics import mean_absolute_error
SS_MAE = mean_absolute_error(test, s_avg.S_Smooth) 
print('SS_MAE: %f' % SS_MAE)
# Out:
# SS_MAE: 3376.349763

# %% [markdown]
# ## Exponential smoothing

# %%
# Exponential Smoothing

exp_avg = test.copy()
fit_e = ExponentialSmoothing(train, seasonal_periods=4 ,trend='additive', seasonal='additive',).fit()
exp_avg['E_Smooth'] = fit_e.forecast(len(test))
plt.figure(figsize=(14,6))
plt.plot( train, label='Train',color="Green")
plt.plot(test, label='Test')
plt.plot(exp_avg['E_Smooth'], label='E_Smooth',color="Red")
plt.legend(loc='best')
plt.title("Exponential Smoothing");
plt.show()
# Out:
# C:\Users\Vadim\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:920: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.

# %%
ES_RMSE = math.sqrt(mean_squared_error(test, exp_avg.E_Smooth))
print('ES_RMSE: %f' % ES_RMSE)
# Out:
# ES_RMSE: 5317.115646

# %%
ES_MAE = mean_absolute_error(test, exp_avg.E_Smooth) 
print('ES_MAE: %f' % ES_MAE)
# Out:
# ES_MAE: 3657.690807

# %% [markdown]
# ## Holt's Linear Trend

# %% [markdown]
# ### Let's create time-series decomposition plot

# %%
#Time-series decomposition plot
from pylab import rcParams
rcParams['figure.figsize'] = 18, 8
res = sm.tsa.seasonal_decompose(y.interpolate(), model='additive')
resplot = res.plot()
resplot.savefig('Seasonal_Decompose.png', dpi=150)

# %%
decom_avg = test.copy()

fit_d = Holt(train).fit(smoothing_level = 0.3, smoothing_slope = 0.01)
decom_avg['Decomp'] = fit_d.forecast(len(test))

plt.figure(figsize=(14,6))
plt.plot(train, label='Train',color="Green")
plt.plot(test, label='Test')
plt.plot(decom_avg['Decomp'], label='Decom',color="Red")
plt.legend(loc='best')
plt.title("Decomposition");
plt.show()

# %%
HL_RMSE = math.sqrt(mean_squared_error(test, decom_avg.Decomp))
print('HL_RMSE: %f' % HL_RMSE)
# Out:
# HL_RMSE: 5008.402424

# %%
HL_MAE = mean_absolute_error(test, decom_avg.Decomp) 
print('HL_MAE: %f' % HL_MAE)
# Out:
# HL_MAE: 4323.081687

# %% [markdown]
# ## Holt-Winters Method

# %%
hw_avg = test.copy()
fit_hw = ExponentialSmoothing(train , seasonal_periods=4 ,trend='add', seasonal='mul',).fit()
hw_avg['Holt_Winter'] = fit_hw.forecast(len(test))
plt.figure(figsize=(16,8))
plt.plot( train, label='Train', color="Green")
plt.plot(test, label='Test', color="Blue")
plt.plot(hw_avg['Holt_Winter'], label='Holt_Winter', color="Red")
plt.legend(loc='best')
plt.show()
# Out:
# C:\Users\Vadim\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:920: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.

# %%
HW_RMSE = math.sqrt(mean_squared_error(test, hw_avg.Holt_Winter))
print('HW_RMSE: %f' % HW_RMSE)
# Out:
# HW_RMSE: 5041.018567

# %%
HW_MAE = mean_absolute_error(test, hw_avg.Holt_Winter) 
print('HW_MAE: %f' % HW_MAE)
# Out:
# HW_MAE: 3614.934442

# %% [markdown]
# ## Preliminary seasonal ARIMA model

# %%
arima_avg = test.copy()
fit_arima = sm.tsa.statespace.SARIMAX(train, order=(5, 1, 4),seasonal_order=(0,1,1,6)).fit()
arima_avg['SARIMA'] = fit_arima.predict(start="2015-12-31", end="2017-06-30", dynamic=True)
plt.figure(figsize=(16,8))
plt.plot( train, label='Train', color="Green")
plt.plot(test, label='Test', color="Blue")
plt.plot(arima_avg['SARIMA'], label='SARIMA', color="Red")
plt.legend(loc='best')
plt.show()
# Out:
# C:\Users\Vadim\anaconda3\lib\site-packages\statsmodels\base\model.py:566: ConvergenceWarning:
#
# Maximum Likelihood optimization failed to converge. Check mle_retvals

# %%
SA_RMSE = math.sqrt(mean_squared_error(test, arima_avg.SARIMA))
print('SA_RMSE: %f' % SA_RMSE)
# Out:
# SA_RMSE: 3995.836604

# %%
from sklearn.metrics import mean_absolute_error
SA_MAE = mean_absolute_error(test, arima_avg.SARIMA) 
print('SA_MAE: %f' % SA_MAE)
# Out:
# SA_MAE: 2789.004479

# %% [markdown]
# ## Seasonal ARIMA models are denoted with the notation parameters (p, d, q) and accountable for data seasonality, trend, and noise :

# %%
p = d = q = range(0, 2)
pdq = list(itertools.product(p, d, q))
seasonal_pdq = [(x[0], x[1], x[2], 12) for x in list(itertools.product(p, d, q))]
print('Examples of parameter combinations for Seasonal ARIMA...')
print('SARIMAX: {} x {}'.format(pdq[1], seasonal_pdq[1]))
print('SARIMAX: {} x {}'.format(pdq[1], seasonal_pdq[2]))
print('SARIMAX: {} x {}'.format(pdq[2], seasonal_pdq[3]))
print('SARIMAX: {} x {}'.format(pdq[2], seasonal_pdq[4]))
# Out:
# Examples of parameter combinations for Seasonal ARIMA...
# SARIMAX: (0, 0, 1) x (0, 0, 1, 12)
# SARIMAX: (0, 0, 1) x (0, 1, 0, 12)
# SARIMAX: (0, 1, 0) x (0, 1, 1, 12)
# SARIMAX: (0, 1, 0) x (1, 0, 0, 12)

# %% [markdown]
# ## Optimal set of parameters that yields the best performance for the SARIMA

# %%
from pmdarima.arima import auto_arima
mod = auto_arima(y, start_p=1, start_q=1,max_p=3, max_q=3, m=25,
                           start_P=0, seasonal=True,
                           d=1, D=1, trace=True,
                           error_action='ignore',  
                           suppress_warnings=True, 
                           stepwise=True)
print(mod.bic())
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(1,1,1)(0,1,1)[25]             : AIC=694.368, Time=0.48 sec
#  ARIMA(0,1,0)(0,1,0)[25]             : AIC=710.823, Time=0.03 sec
#  ARIMA(1,1,0)(1,1,0)[25]             : AIC=700.135, Time=0.17 sec
#  ARIMA(0,1,1)(0,1,1)[25]             : AIC=692.719, Time=0.16 sec
#  ARIMA(0,1,1)(0,1,0)[25]             : AIC=702.382, Time=0.05 sec
#  ARIMA(0,1,1)(1,1,1)[25]             : AIC=694.220, Time=0.27 sec
#  ARIMA(0,1,1)(0,1,2)[25]             : AIC=694.084, Time=0.41 sec
#  ARIMA(0,1,1)(1,1,0)[25]             : AIC=693.967, Time=0.12 sec
#  ARIMA(0,1,1)(1,1,2)[25]             : AIC=696.057, Time=0.81 sec
#  ARIMA(0,1,0)(0,1,1)[25]             : AIC=702.127, Time=0.12 sec
#  ARIMA(0,1,2)(0,1,1)[25]             : AIC=693.054, Time=0.22 sec
#  ARIMA(1,1,0)(0,1,1)[25]             : AIC=inf, Time=0.63 sec
#  ARIMA(1,1,2)(0,1,1)[25]             : AIC=694.457, Time=0.30 sec
#  ARIMA(0,1,1)(0,1,1)[25] intercept   : AIC=inf, Time=0.78 sec
#
# Best model:  ARIMA(0,1,1)(0,1,1)[25]
# Total fit time: 4.596 seconds
# 697.298089423103

# %% [markdown]
# ## Fit seasonal ARIMA model

# %%
mod = sm.tsa.statespace.SARIMAX(y, trend='n', order=(0, 1, 1),seasonal_order=(0, 1, 1, 25),enforce_invertibility=False)
results = mod.fit()
print (results.summary())
# Out:
# C:\Users\Vadim\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning:
#
# No frequency information was provided, so inferred frequency M will be used.
#
# C:\Users\Vadim\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning:
#
# No frequency information was provided, so inferred frequency M will be used.
#                                      SARIMAX Results
# ==========================================================================================
# Dep. Variable:                       Order_Demand   No. Observations:                   60
# Model:             SARIMAX(0, 1, 1)x(0, 1, 1, 25)   Log Likelihood                -341.824
# Date:                            Sun, 18 Apr 2021   AIC                            689.647
# Time:                                    20:32:59   BIC                            694.226
# Sample:                                07-31-2012   HQIC                           691.209
#                                      - 06-30-2017
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1         -0.5771      0.140     -4.113      0.000      -0.852      -0.302
# ma.S.L25      -1.0000      0.290     -3.448      0.001      -1.569      -0.432
# sigma2      2.163e+07   1.34e-08   1.61e+15      0.000    2.16e+07    2.16e+07
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):                 0.82
# Prob(Q):                              0.97   Prob(JB):                         0.66
# Heteroskedasticity (H):               1.53   Skew:                            -0.33
# Prob(H) (two-sided):                  0.49   Kurtosis:                         2.63
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 1.85e+31. Standard errors may be unstable.

# %% [markdown]
# ## Plot diagnostics to investigate unusual model behavior

# %%
results.plot_diagnostics(figsize=(16, 8))
plt.show()

# %% [markdown]
# ## Validate the accuracy of product demand forecast looking at predicted mean for test set of data

# %%
pred = results.get_prediction(start=pd.to_datetime('2016-01-31'), dynamic=False)
pred_ci = pred.conf_int()
print(pred_ci)
ax = y['2012':].plot(label='observed')
pred.predicted_mean.plot(ax=ax, label='Test Forecast', alpha=.7, figsize=(14, 7))
ax.fill_between(pred_ci.index,
                pred_ci.iloc[:, 0],
                pred_ci.iloc[:, 1], color='k', alpha=.2)
ax.set_xlabel('Date')
ax.set_ylabel('Category_001 Demand')
plt.legend()
plt.show()
# Out:
#             lower Order_Demand  upper Order_Demand
# 2016-01-31        21043.117269        43491.538248
# 2016-02-29        25576.495509        48024.916478
# 2016-03-31        19928.194010        42376.614929
# 2016-04-30        19577.471069        42025.891806
# 2016-05-31        22980.027843        45428.447974
# 2016-06-30        20269.728454        42718.146615
# 2016-07-31        19960.440872        42408.852683
# 2016-08-31        21061.200472        43114.886417
# 2016-09-30        29549.997361        50975.200264
# 2016-10-31        33957.549306        55161.127117
# 2016-11-30        26649.530297        47786.478106
# 2016-12-31        19865.269088        40981.686371
# 2017-01-31        22042.963871        43152.997044
# 2017-02-28        23036.701044        44144.740039
# 2017-03-31        18380.122108        39487.536233
# 2017-04-30        19955.133314        41062.351100
# 2017-05-31        23752.300824        44859.456757
# 2017-06-30        24013.350718        45120.487116

# %%
y_forecasted = pred.predicted_mean
print(y_forecasted)
# Out:
# 2016-01-31    32267.327759
# 2016-02-29    36800.705993
# 2016-03-31    31152.404470
# 2016-04-30    30801.681437
# 2016-05-31    34204.237908
# 2016-06-30    31493.937534
# 2016-07-31    31184.646777
# 2016-08-31    32088.043445
# 2016-09-30    40262.598812
# 2016-10-31    44559.338211
# 2016-11-30    37218.004201
# 2016-12-31    30423.477729
# 2017-01-31    32597.980457
# 2017-02-28    33590.720541
# 2017-03-31    28933.829170
# 2017-04-30    30508.742207
# 2017-05-31    34305.878790
# 2017-06-30    34566.918917
# Freq: M, Name: predicted_mean, dtype: float64

# %% [markdown]
# ## Visualizing future product demand forecast

# %%
pred_uc = results.get_forecast(steps=10)
pred_ci = pred_uc.conf_int()

ax = y.plot(label='observed', figsize=(14, 7))
pred_uc.predicted_mean.plot(ax=ax, label='Forecast')
ax.fill_between(pred_ci.index,
                pred_ci.iloc[:, 0],
                pred_ci.iloc[:, 1], color='k', alpha=.25)
ax.set_xlabel('Date')
ax.set_ylabel('Category_001 Demand')
plt.legend()
plt.show()
print(pred_ci)
print(pred_uc)
# Out:
#             lower Order_Demand  upper Order_Demand
# 2017-07-31        27197.113242        48304.243455
# 2017-08-31        26102.233543        49042.978119
# 2017-09-30        26241.161504        50878.877574
# 2017-10-31        26745.788118        52970.607534
# 2017-11-30        23950.342388        51671.397105
# 2017-12-31        20650.275593        49790.762619
# 2018-01-31        22556.328413        53050.206055
# 2018-02-28        21771.564373        53561.245396
# 2018-03-31        22121.604005        55156.288952
# 2018-04-30        18991.035095        53225.473780
# <statsmodels.tsa.statespace.mlemodel.PredictionResultsWrapper object at 0x00000186C1AB9B20>

# %% [markdown]
# ## Our Category_001 predicted demand in January 2017

# %%
pred_uc.predicted_mean[0:1]
# Out:
# 2017-07-31    37750.678348
# Freq: M, Name: predicted_mean, dtype: float64

# %% [markdown]
# ## Root Mean Square Error Comparison Plot

# %%
# create groups for
n_groups = 5
MSE = (SS_RMSE, ES_RMSE, HL_RMSE, HW_RMSE, SA_RMSE)
 
# create plot
fig, ax = plt.subplots()
index = np.arange(n_groups)
bar_width = 0.35
opacity = 0.8
 
 
rects2 = plt.bar(index + bar_width, MSE, bar_width, alpha=opacity, color='b', label='Models')
 
plt.ylabel('Root Mean Square Error')
plt.title('Root Mean Square Error')
plt.xticks(index + bar_width, ('Simple_Smoothing', 'Exponential_Smoothing', 'Holt Linear', 'Holt-Winters', 'Seasonal_ARIMA'))
plt.legend()
